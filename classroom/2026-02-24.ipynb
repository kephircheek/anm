# %%
lst2 = 0

# %% [raw]
# # Head title

# %% [markdown]
# # Head title

# %% [markdown]
# asdfkjsd
# asdfakjsdf
# sadllfkjasdf
# salflkjsdf

# %% [markdown]
# ## Second level title

# %% [raw]
# **bold**
# *italic*

# %% [markdown]
# **bold**
# *italic*

# %%
2 + 2
# Out:
# 4

# %%
myname = 2 + 2

# %%
myname
# Out:
# 4

# %%
myname = 5

# %%
myname
# Out:
# 5

# %%
4 - 2 - 2
# Out:
# 0

# %%
tpl1 = (1, 2, 3)
tpl2 = tpl1

# %% [raw]
# tpl1 = (1, 2, 3)
# tpl2 = (1, 2, 3)

# %%
tpl1
# Out:
# (1, 2, 3)

# %%
tpl2
# Out:
# (1, 2, 3)

# %%
2 + 2
# Out:
# 4

# %%
2.__add__(2)
# Out:
#   Cell In[14], line 1
#     2.__add__(2)
#      ^
# SyntaxError: invalid decimal literal

# %%
tpl1
# Out:
# (1, 2, 3)

# %%
tpl1.__getitem__(0)
# Out:
# 1

# %%
tpl1[0]
# Out:
# 1

# %%
tpl1.count(1)
# Out:
# 1

# %%
tpl1.index(2)
# Out:
# 1

# %%
tpl1
# Out:
# (1, 2, 3)

# %%
(1,3,2,5,3,3,4).index(3)
# Out:
# 1

# %%
(1,3,2,5,3,3,4).index(3, 2)
# Out:
# 4

# %%
long_random_tuple = (1,3,2,5,3,3,4)
long_random_tuple.index(3, long_random_tuple.index(3) + 1)
# Out:
# 4

# %%
tpl = (4, 2, 7)

# %%
tpl[0]
# Out:
# 4

# %%
tpl[0] = 5
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 tpl[0] = 5
#
# TypeError: 'tuple' object does not support item assignment

# %%
tpl_new = (5, tpl[1], tpl[2])
tpl_new
# Out:
# (5, 2, 7)

# %%
lst = [5, 3, 8]
lst3
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[48], line 2
#       1 lst = [5, 3, 8]
# ----> 2 lst3
#
# NameError: name 'lst3' is not defined

# %%
lst3 = lst

# %%
lst2 = lst

# %%
lst[0] = 9
lst
# Out:
# [9, 3, 8]

# %%
lst_magic
# Out:
# [[...], 2, 3]

# %%
tuple, list
# Out:
# [[...], 2, 3]

# %% [raw]
# %pip install pandas

# %%
import pandas as pd

# %%
[[11, 12], [21, 22]]
# Out:
# [[11, 12], [21, 22]]

# %%
df = pd.DataFrame(
    [[11, 12], [21, 22]], 
    columns=["first", "second"], 
    index=["a", "b"]
)
df
# Out:
#    first  second
# a     11      12
# b     21      22

# %%
df.plot()
# Out:
# <Axes: >

# %%
pd.read_xml("")
