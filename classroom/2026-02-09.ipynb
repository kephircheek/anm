# %% [raw]
# Новый
# https://jupyterlite.lazarev.fun

# %% [raw]
# Старый
# https://jupyter.org/try-jupyter/lab/

# %% [markdown]
# # First level header

# %% [markdown]
# ## Second level

# %% [raw]
# Hello world!

# %% [markdown]
# Hello world!

# %% [raw]
# **bold**, _curve_, *curve*,

# %% [markdown]
# **bold**, _curve_, *curve*,

# %% [raw]
# `monospace`

# %% [markdown]
# `monospace`

# %% [raw]
# ```text
# monospace
# monospace
# monospace
# monospace
# monospace
# ```

# %% [markdown]
# ```text
# monospace
# monospace
# monospace
# monospace
# monospace
# ```

# %% [raw]
# $$
#     | \psi \rangle = \sin(xt)
# $$

# %% [markdown]
# $$
#     | \psi \rangle = \sin(xt)
# $$

# %% [markdown]
# My first equation in LaTex $ | \psi \rangle = \sin(xt) $

# %%
x = 2 + 2
2 + 3
# Out:
# 5

# %%
x * 2
# Out:
# 8

# %%
x**4
# Out:
# 256

# %%
import math

# %%
math
# Out:
# <module 'math' (built-in)>

# %% [markdown]
# Before we start, we import some preliminary libraries.

# %%
math.sin(0)
# Out:
# 0.0

# %%
x = 0 
math.sin(x)
# Out:
# 0.0

# %%
a = 3

# %%
math.sin(math.pi)
# Out:
# 1.2246467991473532e-16

# %%
math.pi
# Out:
# 3.141592653589793

# %%
math.comb(1000, 500)
# Out:
# 

# %%
math.comb(1000, 500) * 1.0
# Out:
# 2.7028824094543655e+299

# %%
math .comb(1000, 500) * 1.0 == math.comb(1000, 500)
x = 2

# %%
math.comb(100 0, 500)
# Out:
#   Cell In[30], line 1
#     math.comb(100 0, 500)
#               ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
from math import sin, pi, exp

# %%
sin(pi)
# Out:
# 1.2246467991473532e-16

# %%
sin = 1

# %%
sin(pi)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 sin(pi)
#
# NameError: name 'sin' is not defined
