# %%
# https://ru.wikipedia.org/wiki/%D0%A3%D1%80%D0%B0%D0%B2%D0%BD%D0%B5%D0%BD%D0%B8%D0%B5_%D0%92%D0%B0%D0%BD-%D0%B4%D0%B5%D1%80-%D0%92%D0%B0%D0%B0%D0%BB%D1%8C%D1%81%D0%B0
"https://ru.wikipedia.org/wiki/Уравнение_Ван-дер-Ваальса"
# Out:
#   Cell In[1], line 2
#     https://ru.wikipedia.org/wiki/Уравнение_Ван-дер-Ваальса
#           ^
# SyntaxError: invalid syntax

# %%
"β"
# Out:
# 'β'

# %%
"😊"
# Out:
# '😊'

# %%
"\u03B2"
# Out:
# 'β'

# %%
list("β😊") # mylist[0]
# Out:
# ['β', '😊']

# %%
b"example"
# Out:
# b'example'

# %%
b"пример"
# Out:
#   Cell In[15], line 1
#     b"пример"
#     ^
# SyntaxError: bytes can only contain ASCII literal characters

# %%
get(url)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 get(url)
#
# NameError: name 'get' is not defined

# %%
# %pip install requests

# %%
import requests

# %%
url = (
    "https://ru.wikipedia.org"
    "/wiki"
    "/Уравнение_Ван-дер-Ваальса"
)
url
# Out:
# 'https://ru.wikipedia.org/wiki/Уравнение_Ван-дер-Ваальса'

# %%
requests.get(url)
# Out:
# <Response [200]>

# %%
resp = requests.get(url)
resp
# Out:
# <Response [200]>

# %%
print(*resp.headers.items(), sep="\n")
# Out:
# ('cache-control', 'private, s-maxage=0, max-age=0, must-revalidate, no-transform')
# ('content-language', 'ru')
# ('content-length', '33790')
# ('content-type', 'text/html; charset=UTF-8')
# ('last-modified', 'Thu, 26 Feb 2026 12:44:47 GMT')

# %%
resp.content[:50]
# Out:
# b'<!DOCTYPE html>\n<html class="client-nojs skin-them'

# %%
resp.content
# Out:
# b'<!DOCTYPE html>\n<html class="client-nojs skin-theme-clientpref-thumb-standard" lang="ru" dir="ltr">\n<head>\n<meta charset="UTF-8">\n<title>\xd0\xa3\xd1\x80\xd0\xb0\xd0\xb2\xd0\xbd\xd0\xb5\xd0\xbd\xd0\xb8\xd0\xb5 \xd0\x92\xd0\xb0\xd0\xbd-\xd0\xb4\xd0\xb5\xd1\x80-\xd0\x92\xd0\xb0\xd0\xb0\xd0\xbb\xd1\x8c\xd1\x81\xd0\xb0 \xe2\x80\x94 \xd0\x92\xd0\xb8\xd0\xba\xd0\xb8\xd0\xbf\xd0\xb5\xd0\xb4\xd0\xb8\xd1\x8f</title>\n<script>(function(){var className="client-js skin-theme-clientpref-thumb-standard";var cookie=document.cookie.match(/(?:^|; )ruwikimwclientpreferences=([^;]+)/);if(cookie){cookie[1].split(\'%2C\').forEach(function(pref){className=className.replace(new RegExp(\'(^| )\'+pref.replace(/-clientpref-\\w+$|[^\\w-]+/g,\'\')+\'-clientpref-\\\\w+( |$)\'),\'$1\'+pref+\'$2\');});}document.documentElement.className=className;}());RLCONF={"wgBreakFrames":false,"wgSeparatorTransformTable":[",\\t.","\xc2\xa0\\t,"],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":[
# ...

# %%
resp.text[:50]
# Out:
# '<!DOCTYPE html>\n<html class="client-nojs skin-them'

# %%
"<table" in resp.text
# Out:
# True

# %%
import pandas as pd

# %%
pd.read_html(resp.text)
# Out:
# <ipython-input-21-b3c5e1864e98>:1: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   pd.read_html(resp.text)
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File /lib/python3.13/site-packages/pandas/compat/_optional.py:135, in import_optional_dependency(name, extra, errors, min_version)
#     134 try:
# --> 135     module = importlib.import_module(name)
#     136 except ImportError:
#
# File /lib/python313.zip/importlib/__init__.py:88, in import_module(name, package)
#      87         level += 1
# ---> 88 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1387, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1360, in _find_and_load(name, import_)
#
# ...

# %%
# %pip install lxml

# %%
type(pd.read_html(resp.text))
# Out:
# <ipython-input-25-24a9bd6d47e4>:1: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   type(pd.read_html(resp.text))
# list

# %%
len(pd.read_html(resp.text))
# Out:
# <ipython-input-26-26943cdf4262>:1: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   len(pd.read_html(resp.text))
# 3

# %%
tables = pd.read_html(resp.text)
tables[0]
# Out:
# <ipython-input-27-57be5fd54d1d>:1: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text)
#                   Вещество  a,  Па·м6·моль−2  b,  10−6 м3·моль−1
# 0                  Азот N2              1370                 387
# 1               Аммиак NH3              4225                 371
# 2                 Аргон Ar              1355                 320
# 3            Ацетилен C2H2              4516                 522
# 4                 Бром Br2               975                 591
# 5         Бромоводород HBr              4500                 442
# 6              Бутан C4H10              1389                1164
# 7                 Вода H2O              5537                 305
# 8               Водород H2              2452                 265
# 9     Гексафторид серы SF6              7857                 879
# ...

# %%
tables = pd.read_html(
    resp.text, 
    decimal=",", 
    thousands=None,
)
tables[0]
# Out:
# <ipython-input-28-c1968ee0da0d>:1: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(
#                   Вещество  a,  Па·м6·моль−2  b,  10−6 м3·моль−1
# 0                  Азот N2           0.13700                38.7
# 1               Аммиак NH3           0.42250                37.1
# 2                 Аргон Ar           0.13550                32.0
# 3            Ацетилен C2H2           0.45160                52.2
# 4                 Бром Br2           0.97500                59.1
# 5         Бромоводород HBr           0.45000                44.2
# 6              Бутан C4H10           1.38900               116.4
# 7                 Вода H2O           0.55370                30.5
# 8               Водород H2           0.02452                26.5
# 9     Гексафторид серы SF6           0.78570                87.9
# ...
